# %%
# !pip install opendatasets --quiet

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/marquis03/bean-leaf-lesions-classification")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: Pranjal_3_Bhardwaj
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/marquis03/bean-leaf-lesions-classification

# %%
import torch
from torch import nn
from torch.optim import Adam
from torchvision.transforms import transforms
from torch.utils.data import DataLoader, Dataset
from torchvision import models
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import numpy as np
import os

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
train_df = pd.read_csv("bean-leaf-lesions-classification/train.csv")
val_df = pd.read_csv("bean-leaf-lesions-classification/val.csv")

train_df["image:FILE"] = "bean-leaf-lesions-classification/" + train_df["image:FILE"]
val_df["image:FILE"] = "bean-leaf-lesions-classification/" + val_df["image:FILE"]

train_df.head()
# Out:
#                                           image:FILE  category
# 0  bean-leaf-lesions-classification/train/healthy...         0
# 1  bean-leaf-lesions-classification/train/healthy...         0
# 2  bean-leaf-lesions-classification/train/healthy...         0
# 3  bean-leaf-lesions-classification/train/healthy...         0
# 4  bean-leaf-lesions-classification/train/healthy...         0

# %%
train_df["category"].unique()
# Out:
# array([0, 1, 2])

# %%
print(train_df.shape)
print(val_df.shape)
# Out:
# (1034, 2)
# (133, 2)

# %%
print(train_df["category"].value_counts())
# Out:
# category
# 2    348
# 1    345
# 0    341
# Name: count, dtype: int64

# %%
transform = transforms.Compose([ #Making a single pipeline for preprocessing the image data
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.ConvertImageDtype(torch.float)
])

# %%
class CustomDataset(Dataset):
  def __init__(self, dataframe, transform):
    self.dataframe = dataframe
    self.transform = transform
    self.labels = torch.tensor(dataframe["category"]).to(device)

  def __len__(self):
    return self.dataframe.shape[0] #Only outputting the number of rows

  def __getitem__(self, idx):
    img_path = self.dataframe.iloc[idx, 0]
    label = self.labels[idx]
    image = Image.open(img_path)
    if self.transform:
      image = (self.transform(image)/255.0).to(device) #Normalizing

    return image, label

# %%
train_dataset = CustomDataset(dataframe = train_df, transform = transform)
val_dataset = CustomDataset(dataframe = val_df, transform = transform)

# %%
n_rows = 3
n_cols = 3

d, axarr = plt.subplots(n_rows, n_cols)

for row in range(n_rows):
  for col in range(n_cols):
    image = train_dataset[np.random.randint(0, train_dataset.__len__())][0].cpu() #CPU because we are not training but visualizing the data
    axarr[row, col].imshow((image*255.0).squeeze().permute(1,2,0)) #.permute() rearranges the dimensions of a tensor according to a given order of axes. It doesn’t change the data itself, just how it's viewed
    axarr[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
LR = 1e-3
BATCH_SIZE = 4
EPOCHS = 15

# %%
train_loader = DataLoader(train_dataset, batch_size = BATCH_SIZE, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size = BATCH_SIZE, shuffle = True)

# %%
googlenet_model = models.googlenet(weights = "DEFAULT")

# %%
for param in googlenet_model.parameters():
  param.requires_grad = True #Allowing parameters to learn again

# %%
googlenet_model.fc #Viewing info about the last layer
#Here there 1000 class output, but we only want 3
#fc -> FULLY CONNECTED Dense Layer
# Out:
# Linear(in_features=1024, out_features=1000, bias=True)

# %%
num_classes = len(train_df["category"].unique())
num_classes
# Out:
# 3

# %%
googlenet_model.fc = torch.nn.Linear(googlenet_model.fc.in_features, num_classes) #Changing the output number to 3
googlenet_model.fc
# Out:
# Linear(in_features=1024, out_features=3, bias=True)

# %%
googlenet_model.to(device)
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
loss_fun = nn.CrossEntropyLoss()
optimizer = Adam(googlenet_model.parameters(), lr = LR)

total_loss_train_plot = []
total_acc_train_plot = []

for epoch in range(EPOCHS):
  total_acc_train = 0
  total_loss_train = 0

  for inputs, labels in train_loader:
    optimizer.zero_grad()
    outputs = googlenet_model(inputs)
    train_loss = loss_fun(outputs, labels)
    total_loss_train += train_loss.item()

    train_loss.backward()

    train_acc = (torch.argmax(outputs, axis = 1) == labels).sum().item()
    total_acc_train += train_acc
    optimizer.step()

  total_loss_train_plot.append(round(total_loss_train/1000, 4))
  total_acc_train_plot.append(round(total_acc_train/train_dataset.__len__()*100, 4))
  print(f"Epoch {epoch+1}/{EPOCHS}, Train Loss: {round(total_loss_train/1000, 4)}, Train Accuracy: {round(total_acc_train/train_dataset.__len__()*100, 4)} %")
# Out:
# Epoch 1/15, Train Loss: 0.1552, Train Accuracy: 77.9497 %
# Epoch 2/15, Train Loss: 0.1387, Train Accuracy: 78.9168 %
# Epoch 3/15, Train Loss: 0.1283, Train Accuracy: 82.3017 %
# Epoch 4/15, Train Loss: 0.1356, Train Accuracy: 79.4971 %
# Epoch 5/15, Train Loss: 0.1067, Train Accuracy: 85.0097 %
# Epoch 6/15, Train Loss: 0.1144, Train Accuracy: 82.6886 %
# Epoch 7/15, Train Loss: 0.0955, Train Accuracy: 86.8472 %
# Epoch 8/15, Train Loss: 0.0967, Train Accuracy: 85.1064 %
# Epoch 9/15, Train Loss: 0.0876, Train Accuracy: 86.1702 %
# Epoch 10/15, Train Loss: 0.0865, Train Accuracy: 86.9439 %
# Epoch 11/15, Train Loss: 0.0706, Train Accuracy: 89.4584 %
# Epoch 12/15, Train Loss: 0.0758, Train Accuracy: 88.3946 %
# Epoch 13/15, Train Loss: 0.0644, Train Accuracy: 91.1025 %
# Epoch 14/15, Train Loss: 0.0687, Train Accuracy: 90.0387 %
# Epoch 15/15, Train Loss: 0.054, Train Accuracy: 92.6499 %

# %%
with torch.no_grad():
  total_acc_test = 0

  for input, labels in val_loader:
    prediction = googlenet_model(input)
    acc = (torch.argmax(prediction, axis = 1) == labels).sum().item()
    total_acc_test += acc

# %%
print(round(total_acc_test/val_dataset.__len__()*100, 2))
# Out:
# 91.73

# %%
googlenet_model = models.googlenet(weights = "DEFAULT") #This is the true Tranfer Learning

for param in googlenet_model.parameters():
  param.googlenet_model = False

googlenet_model.fc = torch.nn.Linear(googlenet_model.fc.in_features, num_classes)
googlenet_model.fc.requires_grad = True
googlenet_model.to(device)
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
loss_fun = nn.CrossEntropyLoss()
optimizer = Adam(googlenet_model.parameters(), lr = LR)

total_loss_train_plot = []
total_acc_train_plot = []

for epoch in range(EPOCHS):
  total_acc_train = 0
  total_loss_train = 0

  for inputs, labels in train_loader:
    optimizer.zero_grad()
    outputs = googlenet_model(inputs)
    train_loss = loss_fun(outputs, labels)
    total_loss_train += train_loss.item()

    train_loss.backward()

    train_acc = (torch.argmax(outputs, axis = 1) == labels).sum().item()
    total_acc_train += train_acc
    optimizer.step()

  total_loss_train_plot.append(round(total_loss_train/1000, 4))
  total_acc_train_plot.append(round(total_acc_train/train_dataset.__len__()*100, 4))
  print(f"Epoch {epoch+1}/{EPOCHS}, Train Loss: {round(total_loss_train/1000, 4)}, Train Accuracy: {round(total_acc_train/train_dataset.__len__()*100, 4)} %")
# Out:
# Epoch 1/15, Train Loss: 0.2465, Train Accuracy: 57.9304 %
# Epoch 2/15, Train Loss: 0.2104, Train Accuracy: 64.7969 %
# Epoch 3/15, Train Loss: 0.1884, Train Accuracy: 70.1161 %
# Epoch 4/15, Train Loss: 0.1823, Train Accuracy: 72.147 %
# Epoch 5/15, Train Loss: 0.1641, Train Accuracy: 74.7582 %
# Epoch 6/15, Train Loss: 0.1508, Train Accuracy: 76.5957 %
# Epoch 7/15, Train Loss: 0.1288, Train Accuracy: 79.5938 %
# Epoch 8/15, Train Loss: 0.1434, Train Accuracy: 77.9497 %
# Epoch 9/15, Train Loss: 0.1176, Train Accuracy: 81.2379 %
# Epoch 10/15, Train Loss: 0.1223, Train Accuracy: 82.882 %
# Epoch 11/15, Train Loss: 0.1004, Train Accuracy: 85.0097 %
# Epoch 12/15, Train Loss: 0.0985, Train Accuracy: 86.4603 %
# Epoch 13/15, Train Loss: 0.1059, Train Accuracy: 84.5261 %
# Epoch 14/15, Train Loss: 0.0776, Train Accuracy: 88.3946 %
# Epoch 15/15, Train Loss: 0.0828, Train Accuracy: 88.1044 %

# %%
with torch.no_grad():
  total_acc_test = 0

  for input, labels in val_loader:
    prediction = googlenet_model(input)
    acc = (torch.argmax(prediction, axis = 1) == labels).sum().item()
    total_acc_test += acc

# %%
print(round(total_acc_test/val_dataset.__len__()*100, 2))
# Out:
# 87.22

# %%
#We can see that by training only the last layer the accuracy is less than by training the entire learnt model
